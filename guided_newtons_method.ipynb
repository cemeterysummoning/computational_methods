# %%
using Plots
using MTH229

# %%
f(x) = x^3 - 2x - 5
plot(f, -3, 3)

# %%
fp(x) = 3x^2 - 2
x = 2
x = x - f(x) / fp(x)
x, f(x)
# Out:
# (2.1, 0.06100000000000083)

# %%
x0 = 2
x1 = x
plot(f, 1, 3, legend=false)
plot!([x0, x0, x1], [0, f(x0), 0])
scatter!([x0, x1], [0, 0])

# %%
x = x - f(x) / fp(x)
println(x, " ", f(x))

x = x - f(x) / fp(x)
println(x, " ", f(x))

x = x - f(x) / fp(x)
println(x, " ", f(x))

x = x - f(x) / fp(x)
println(x, " ", f(x))
# Out:
# 2.094568121104185 0.00018572317327247845
# 2.094551481698199 1.7397612239733462e-9
# 2.0945514815423265 -8.881784197001252e-16
# 2.0945514815423265 -8.881784197001252e-16

# %%
f(x) = x^2 - 15
fp(x) = 2x
x = 4

x = x - f(x) / fp(x)
x = x - f(x) / fp(x)
x = x - f(x) / fp(x)

println(x, " ", f(x))
# Out:
# 3.8729833462074525 2.7711166694643907e-13

# %%
f(x) = sin(x)
fp(x) = cos(x)
x = 3
x = x - f(x) / fp(x)
x = x - f(x) / fp(x)
x = x - f(x) / fp(x)
x = x - f(x) / fp(x)
x = x - f(x) / fp(x)

println(x, " ", f(x))
# Out:
# 3.141592653589793 1.2246467991473532e-16

# %%
f(x) = x^2 - 3^x
fp(x) = 2x - 3^x * log(3)
x = 0

x = x - f(x) / fp(x)
x = x - f(x) / fp(x)
x = x - f(x) / fp(x)
x = x - f(x) / fp(x)
x = x - f(x) / fp(x)

println(x, " ", f(x))
# Out:
# -0.6860267245362514 5.551115123125783e-17

# %%
function nm(f, fp, x)
    xnew, xold = x, Inf
    fn, fo = f(xnew), Inf

    tol = 1e-14
    ctr = 1

    while (ctr < 100) && (abs(xnew - xold) > tol) && (abs(fn - fo) > tol)
        x = xnew - f(xnew) / fp(xnew)

        xnew, xold = x, xnew
        fn, fo = f(xnew), fn
        ctr = ctr + 1
    end

    if ctr == 100 
        error("did not converge in under 100 steps")
    else 
        xnew, ctr
    end
end
# Out:
# nm (generic function with 1 method)

# %%
f(x) = x^3 - 5x + 1
fp(x) = 3x^2 - 5
xstar, ctr = nm(f, fp, 0)
# Out:
# (0.20163967572340466, 6)

# %%
f(x) = exp(x) - x^4
x = 8
xstar = newton(f, 8, verbose=true)
# Out:
# Results of univariate zero finding:
#
# * Converged to: 8.6131694564414
# * Algorithm: Roots.Newton()
# * iterations: 8
# * function evaluations ≈ 16
# * stopped as x_n ≈ x_{n-1} using atol=xatol, rtol=xrtol
#
# Trace:
# x₁ = 8,	 fx₁ = -1115.0420129582717
# x₂ = 9.1951685161021075,	 fx₂ = 2700.5339924159998
# x₃ = 8.7944708020788642,	 fx₃ = 615.76735783715776
# x₄ = 8.6356413896038262,	 fx₄ = 67.416233795479457
# x₅ = 8.6135576545997825,	 fx₅ = 1.1446528211590703
# x₆ = 8.6131695743314562,	 fx₆ = 0.00034750863687804667
# x₇ = 8.6131694564414101,	 fx₇ = 3.3651303965598345e-11
# x₈ = 8.6131694564413994,	 fx₈ = 1.8189894035458565e-12
# x₉ = 8.6131694564413994,	 fx₉ = 1.8189894035458565e-12
# 8.6131694564414

# %%
f(x) = sin(x) - cos(4 * x)
newton(f, π/8, verbose=true)
# Out:
# Results of univariate zero finding:
#
# * Converged to: 0.3141592653589793
# * Algorithm: Roots.Newton()
# * iterations: 4
# * function evaluations ≈ 8
# * stopped as |f(x_n)| ≤ max(δ, |x|⋅ϵ) using δ = atol, ϵ = rtol
#
# Trace:
# x₁ = 0.39269908169872414,	 fx₁ = 0.38268343236508973
# x₂ = 0.31497918017832427,	 fx₂ = 0.0039004790271633394
# x₃ = 0.31415959035712876,	 fx₃ = 1.5454582837914899e-06
# x₄ = 0.31415926535903083,	 fx₄ = 2.4491519923230953e-13
# x₅ = 0.31415926535897931,	 fx₅ = -5.5511151231257827e-17
# 0.3141592653589793

# %%
x2, x1 = 1, 2
f(x) = x^2 - 2 
fp(x1, x2) = (f(x1) - f(x2)) / (x1 - x2)
x2, x1 = x2 - f(x2) / fp(x1, x2), x2
# Out:
# (1.3333333333333333, 1)

# %%
f(x) = cos(x) - x^3
x1, x0 = 1, 1/2
fp(x0, x1) = (f(x0) - f(x1)) / (x0 - x1)
x1, x0 = x1 - f(x1) / fp(x0, x1), x1
println(x1, " ", x0)
x1, x0 = x1 - f(x1) / fp(x0, x1), x1
println(x1, " ", x0)
x1, x0 = x1 - f(x1) / fp(x0, x1), x1
println(x1, " ", x0)
x1, x0 = x1 - f(x1) / fp(x0, x1), x1
println(x1, " ", x0)
x1, x0 = x1 - f(x1) / fp(x0, x1), x1
println(x1, " ", x0)
x1, x0 = x1 - f(x1) / fp(x0, x1), x1
println(x1, " ", x0)
x1, x0 = x1 - f(x1) / fp(x0, x1), x1
println(x1, " ", x0)
# Out:
# 0.810399578872862 1
# 0.8586640585120002 0.810399578872862
# 0.8658538071318002 0.8586640585120002
# 0.8654715115979841 0.8658538071318002
# 0.8654740321722509 0.8654715115979841
# 0.8654740331016167 0.8654740321722509
# 0.8654740331016144 0.8654740331016167

# %%
f(x) = x^5 + x - 1
x1, x0 = 1, 1/2
fp(x0, x1) = (f(x0) - f(x1)) / (x0 - x1)
x1, x0 = x1 - f(x1) / fp(x0, x1), x1
println(x1, " ", x0)
x1, x0 = x1 - f(x1) / fp(x0, x1), x1
println(x1, " ", x0)
x1, x0 = x1 - f(x1) / fp(x0, x1), x1
println(x1, " ", x0)
x1, x0 = x1 - f(x1) / fp(x0, x1), x1
println(x1, " ", x0)
x1, x0 = x1 - f(x1) / fp(x0, x1), x1
println(x1, " ", x0)
x1, x0 = x1 - f(x1) / fp(x0, x1), x1
println(x1, " ", x0)
x1, x0 = x1 - f(x1) / fp(x0, x1), x1
println(x1, " ", x0)
# Out:
# 0.6595744680851063 1
# 0.7199516288115612 0.6595744680851063
# 0.7605022125355125 0.7199516288115612
# 0.7545529131961578 0.7605022125355125
# 0.7548746764702177 0.7545529131961578
# 0.7548776678387935 0.7548746764702177
# 0.754877666246685 0.7548776678387935

# %%
f(x) = exp(x) - x^4
plot(f, -5, 9)
find_zero.(f, [-1, 2, 9])
# Out:
# 3-element Vector{Float64}:
#  -0.8155534188089607
#   1.4296118247255556
#   8.6131694564414

# %%
f(x) = cos(x^2)^2
plot(f', -1, 2)

# %%
f(x) = 4x^4 - 5x^3 + 4x^2 - 20x - 6
newton(f, 0, verbose=true)
# Out:
# Results of univariate zero finding:
#
# * Converged to: -0.27798094871260326
# * Algorithm: Roots.Newton()
# * iterations: 5
# * function evaluations ≈ 10
# * stopped as f(x_n) = 0
#
# Trace:
# x₁ = 0,	 fx₁ = -6
# x₂ = -0.29999999999999999,	 fx₂ = 0.52740000000000009
# x₃ = -0.27819038954594327,	 fx₃ = 0.0049697664887027315
# x₄ = -0.27798096724937527,	 fx₄ = 4.3981526864911302e-07
# x₅ = -0.27798094871260343,	 fx₅ = 4.4408920985006262e-15
# x₆ = -0.27798094871260326,	 fx₆ = 0
# -0.27798094871260326

# %%
f(x) = x^x - 2
newton(f, 1, verbose=true)
# Out:
# Results of univariate zero finding:
#
# * Converged to: 1.5596104694623694
# * Algorithm: Roots.Newton()
# * iterations: 7
# * function evaluations ≈ 14
# * stopped as f(x_n) = 0
#
# Trace:
# x₁ = 1,	 fx₁ = -1
# x₂ = 2,	 fx₂ = 2
# x₃ = 1.7046919454251794,	 fx₃ = 0.48247518244629983
# x₄ = 1.5779445574762705,	 fx₄ = 0.053892848419517136
# x₅ = 1.5599245375170789,	 fx₅ = 0.00090757156729059929
# x₆ = 1.5596105625771766,	 fx₆ = 2.6899679994585313e-07
# x₇ = 1.5596104694623776,	 fx₇ = 2.3980817331903381e-14
# x₈ = 1.5596104694623694,	 fx₈ = 0
# 1.5596104694623694

# %%
f(x) = x^5 - x - 1
plot(f, -2, 2)
find_zero(f, 2)
# Out:
# 1.1673039782614187

# %%
f(x) = 5 / sin(x) + 8 / cos(x) 
find_zero(f', π/4)
# Out:
# 0.7073827215431158

# %%
tangent(f, c) = x -> f(c) + f'(c) * (x - c)
f(x) = x^2 - 3x + 5
h(x) = tangent(f, 1)(x) - tangent(f, 3)(x)
find_zero(h, 1)
# Out:
# 2.0

# %% [markdown]
# $$f(x) = x^{\frac{1}{3}}$$
# $$x - \frac{f(x)}{f'(x)} = x - \frac{x^{\frac{1}{3}}}{\frac{1}{3} x^{\frac{-2}{3}}}$$
# $$x - \frac{x}{\frac{1}{3}} = x - 3x = -2x$$

# %%
f(x) = (x - 2)^7 * (x - 3) * (x - 4)
plot(f, -3, 3)
